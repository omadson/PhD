# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
def get_holidays(years):
    holidays = list()
    for year in years:
        holidays_wrong = pd.read_json('https://api.calendario.com.br/?json=true&ano=%s&ibge=2304400&token=bWFkc29uZGRpYXNAZ21haWwuY29tJmhhc2g9MTIzNDc0NTU0' % year).date.astype('str').values
#         holidays.extend(['%s-%s-%s' % (x.split('-')[0], x.split('-')[1], x.split('-')[2]) for x in holidays_wrong])
        holidays.extend(holidays_wrong)
    return holidays

# %%
path_name = '../data/climate/'
file_names_pr = ['24279', '24319', '24320', '24321']
file_names_t  = ['225', '572']

df_final = pd.DataFrame()

for file_name in file_names_pr:
    df_ = pd.read_csv(path_name+'pr/'+file_name+'.csv')
    df_final[file_name] = df_['pr']

for file_name in file_names_t:
    df_final['avg_tmp_'+file_name] = pd.read_csv(path_name+'t2m/'+file_name+'.csv')['avg_tmp']
    df_final['max_tmp_'+file_name] = pd.read_csv(path_name+'t2mmax/'+file_name+'.csv')['max_tmp']
    df_final['min_tmp_'+file_name] = pd.read_csv(path_name+'t2mmin/'+file_name+'.csv')['min_tmp']
    
df_['year']  = df_['year'].astype('object')
df_['month'] = df_['month'].astype('object')
df_['day']   = df_['day'].astype('object')

df_['dia'] = df_.apply(lambda x: '%s-%s-%s' % (x['year'], str(x['month']).zfill(2), str(x['day']).zfill(2)), axis=1)

df_final = df_final.assign(weekday=df_.apply(lambda x: datetime.strptime('%s-%s-%s' % (x['year'],x['month'],x['day']),'%Y-%m-%d').weekday(), axis=1),
                           dia=df_['dia'])

holidays_list = get_holidays(['2014','2015','2016', '2017'])
df_final = df_final.assign(holiday=df_.apply(lambda x: 1 if '%s-%s-%s' % (str(x['year']), str(x['month']).zfill(2),str(x['day']).zfill(2)) in holidays_list else 0, axis=1))
df_final = df_final.assign(workingday=df_final.apply(lambda x: 0 if x['holiday'] == 1 or x['weekday'] in [6,7] else 1, axis=1))
df_final = df_final.assign(avg_pr=df_final[file_names_pr].mean(axis=1))
df_final = df_final.assign(max_pr=df_final[file_names_pr].max(axis=1))
df_final = df_final.assign(min_pr=df_final[file_names_pr].min(axis=1))
df_final = df_final.assign(avg_tmp=df_final[['avg_tmp_225','avg_tmp_572']].mean(axis=1))
df_final = df_final.assign(min_tmp=df_final[['min_tmp_225','min_tmp_572']].mean(axis=1))
df_final = df_final.assign(max_tmp=df_final[['max_tmp_225','max_tmp_572']].mean(axis=1))
df_final = df_final.drop(['avg_tmp_225','avg_tmp_572','min_tmp_225','min_tmp_572','max_tmp_225','max_tmp_572'], axis=1)
df_final = df_final.drop(file_names_pr, axis=1)
# df_final = df_final.fillna(df_final.mean())
df_final = df_final.interpolate()

df_final = df_final.set_index('dia')
df_final = df_final.iloc[349:]

df_viagens = pd.read_csv('../data/bicicletar/graph_datasets/rides_per_sex.csv', index_col='dia')

# %%
pd.concat([df_viagens,df_final], axis=1).to_csv('../data/bicicletar/graph_datasets/climate_rides.csv')
# Out:
# /home/renan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   """Entry point for launching an IPython kernel.

# %%
aa = pd.concat([df_final, df_viagens], axis=1)
aa = aa.fillna(0)
aa['date'] = aa.index
aa.to_json('/home/omadson/Downloads/sources391/data/tmp.json',orient='records')
# Out:
# /home/omadson/.local/lib/python3.5/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
# aa['date'] == aa.index

# %%
year = 2014
holidays_wrong = pd.read_json('https://api.calendario.com.br/?json=true&ano=%s&ibge=2304400&token=bWFkc29uZGRpYXNAZ21haWwuY29tJmhhc2g9MTIzNDc0NTU0' % year).date.astype('str').values

# %%
aa[aa.index == '2017-12-31'][['M_0','F_0','O_0']]
# Out:
#               M_0    F_0  O_0
# 2017-12-31  234.0  111.0  0.0

# %%
aa[aa.index == '2015-01-01']
# Out:
#             weekday  holiday  workingday  avg_pr  max_pr  min_pr  avg_tmp  \
# 2015-01-01        3        1           0     0.0     0.0     0.0  27.3775
#
#             min_tmp  max_tmp    M_0    F_0  O_0   M_3   F_3  O_3  M_4  F_4  \
# 2015-01-01     24.7     31.6  274.0  243.0  5.0  15.0  10.0  0.0  3.0  0.0
#
#             O_4        date
# 2015-01-01  0.0  2015-01-01

# %%
year = 2015
pd.read_json('https://api.calendario.com.br/?json=true&ano=%s&ibge=2304400&token=bWFkc29uZGRpYXNAZ21haWwuY29tJmhhc2g9MTIzNDc0NTU0' % year)
# Out:
#          date                                        description  \
# 0  2015-01-01  O Ano-Novo ou Réveillon é um evento que aconte...
# 1  2015-02-16  Ponto Facultativo, ou seja, cabe às empresas e...
# 2  2015-02-17  Carnaval NÃO é um feriado oficial, é Ponto Fac...
# 3  2015-02-18                      Ponto Facultativo até às 14h.
# 4  2015-03-19                       Padroeiro do Estado do Ceará
# 5  2015-03-19  Dia de São José, padroeiro do estado do Ceará,...
# 6  2015-03-25  É a data magna onde ocorrem as comemorações do...
# 7  2015-01-04  Dia da mentira, dia das petas, dia dos tolos o...
# 8  2015-03-04  Também chamada de "Sexta Feira da Paixão" é a ...
# 9  2015-03-04   conforme a Lei nº 8796 de 09 de dezembro de 2003
# 10 2015-05-04  A Páscoa é um evento religioso cristão, normal...
# 11 2015-04-13          conforme Lei nº 7535, de 16 de junho 1994
# 12 2015-04-21  Joaquim José da Silva Xavier, o Tiradentes foi...
# 13 2015-01-05  O Dia do Trabalhador ou Dia Internacional dos ...
# 14 2015-10-05  O Dia das Mães teve a sua origem no princípio ...
# 15 2015-04-06  Ponto Facultativo no País, mas Feriado Municip...
# 16 2015-04-06   conforme a Lei nº 8796 de 09 de dezembro de 2003
# 17 2015-12-06  O Dia dos Namorados ou Dia de São Valentim é u...
# 18 2015-09-08  Em 1909, nos Estados Unidos, Sonora Luise reso...
# 19 2015-08-15  Nossa Senhora da Assunção, Padroeira de Fortal...
# 20 2015-07-09  O Dia da Indepência do Brasil, oficialmente a ...
# 21 2015-12-10  Nossa Senhora da Conceição Aparecida é a padro...
# 22 2015-10-15  FERIADO ESCOLAR - No dia 15 de outubro de 1827...
# 23 2015-10-17  Comemoração do dia do comércio. Em algumas cid...
# 24 2015-10-28  O dia do servidor público é feriado apenas par...
# 25 2015-02-11  O Dia de Finados ou Dia dos Fiéis Defuntos, (c...
# 26 2015-11-15  A Proclamação da República foi um levante polí...
# 27 2015-11-20  Apesar de ser comemorado em todo o território ...
# 28 2015-12-25  O Natal é comemorado anualmente em 25 de Dezem...
#
#                                                  link  \
# 0   http://www.calendario.com.br/feriados-nacionai...
# 1   http://www.calendario.com.br/feriados-nacionai...
# 2   http://www.calendario.com.br/feriados-nacionai...
# 3   http://www.calendario.com.br/feriados-nacionai...
# 4
# 5    http://216.59.16.201:8080/sapl/sapl_documento...
# 6
# 7
# 8   http://www.calendario.com.br/feriados-nacionai...
# 9    http://216.59.16.201:8080/sapl/sapl_documento...
# 10
# 11  http://216.59.16.201:8080/sapl/sapl_documentos...
# 12  http://www.calendario.com.br/feriados-nacionai...
# 13  http://www.calendario.com.br/feriados-nacionai...
# 14
# 15  http://www.calendario.com.br/feriados-nacionai...
# 16   http://216.59.16.201:8080/sapl/sapl_documento...
# 17
# 18
# 19   http://216.59.16.201:8080/sapl/sapl_documento...
# 20  http://www.calendario.com.br/feriados-nacionai...
# 21  http://www.calendario.com.br/feriados-nacionai...
# 22  http://www.calendario.com.br/docs/dia-do-profe...
# 23
# 24
# 25  http://www.calendario.com.br/feriados-nacionai...
# 26  http://www.calendario.com.br/feriados-nacionai...
# 27  http://www.calendario.com.br/feriados-nacionai...
# 28  http://www.calendario.com.br/feriados-nacionai...
#
#                         name  \
# 0                   Ano Novo
# 1                   Carnaval
# 2                   Carnaval
# 3                   Carnaval
# 4            Dia de São José
# 5                   São José
# 6        Data Magna do Ceará
# 7             Dia da Mentira
# 8          Sexta-Feira Santa
# 9          Sexta-feira Santa
# 10                    Páscoa
# 11  Aniversário de Fortaleza
# 12         Dia de Tiradentes
# 13           Dia do Trabalho
# 14              Dia das Mães
# 15            Corpus Christi
# 16            Corpus Christi
# 17         Dia dos Namorados
# 18              Dia dos Pais
# 19    N. Senhora da Assunção
# 20   Independência do Brasil
# 21   Nossa Senhora Aparecida
# 22          Dia do Professor
# 23           Dia do Comércio
# 24   Dia do Servidor Público
# 25            Dia de Finados
# 26  Proclamação da República
# 27         Consciência Negra
# 28                     Natal
#
#                                       raw_description               type  \
# 0                                                 NaN   Feriado Nacional
# 1                                                 NaN        Facultativo
# 2                                                 NaN        Facultativo
# 3                                                 NaN        Facultativo
# 4                        Padroeiro do Estado do Ceará        Facultativo
# 5   Dia de São José, padroeiro do estado do Ceará,...  Feriado Municipal
# 6   É a data magna onde ocorrem as comemorações do...   Feriado Estadual
# 7                                                 NaN   Dia Convencional
# 8                                                 NaN   Feriado Nacional
# 9    conforme a Lei nº 8796 de 09 de dezembro de 2003  Feriado Municipal
# 10                                                NaN   Dia Convencional
# 11          conforme Lei nº 7535, de 16 de junho 1994  Feriado Municipal
# 12                                                NaN   Feriado Nacional
# 13                                                NaN   Feriado Nacional
# 14                                                NaN   Dia Convencional
# 15                                                NaN        Facultativo
# 16   conforme a Lei nº 8796 de 09 de dezembro de 2003  Feriado Municipal
# 17                                                NaN   Dia Convencional
# 18                                                NaN   Dia Convencional
# 19  Nossa Senhora da Assunção, Padroeira de Fortal...  Feriado Municipal
# 20                                                NaN   Feriado Nacional
# 21                                                NaN   Feriado Nacional
# 22                                                NaN        Facultativo
# 23                                                NaN   Dia Convencional
# 24                                                NaN        Facultativo
# 25                                                NaN   Feriado Nacional
# 26                                                NaN   Feriado Nacional
# 27                                                NaN   Dia Convencional
# 28                                                NaN   Feriado Nacional
#
#     type_code
# 0           1
# 1           4
# 2           4
# 3           4
# 4           4
# 5           3
# 6           2
# 7           9
# 8           1
# 9           3
# 10          9
# 11          3
# 12          1
# 13          1
# 14          9
# 15          4
# 16          3
# 17          9
# 18          9
# 19          3
# 20          1
# 21          1
# 22          4
# 23          9
# 24          4
# 25          1
# 26          1
# 27          9
# 28          1

# %%
year = 2014
pd.read_json('https://api.calendario.com.br/?json=true&ano=%s&ibge=2304400&token=bWFkc29uZGRpYXNAZ21haWwuY29tJmhhc2g9MTIzNDc0NTU0' % year)
# Out:
#          date                                        description  \
# 0  2014-01-01  O Ano-Novo ou Réveillon é um evento que aconte...
# 1  2014-03-03  Ponto Facultativo, ou seja, cabe às empresas e...
# 2  2014-04-03  Carnaval NÃO é um feriado oficial, é Ponto Fac...
# 3  2014-05-03                      Ponto Facultativo até às 14h.
# 4  2014-03-19                       Padroeiro do Estado do Ceará
# 5  2014-03-19  Dia de São José, padroeiro do estado do Ceará,...
# 6  2014-03-25  É a data magna onde ocorrem as comemorações do...
# 7  2014-01-04  Dia da mentira, dia das petas, dia dos tolos o...
# 8  2014-04-13          conforme Lei nº 7535, de 16 de junho 1994
# 9  2014-04-18  Também chamada de "Sexta Feira da Paixão" é a ...
# 10 2014-04-18   conforme a Lei nº 8796 de 09 de dezembro de 2003
# 11 2014-04-20  A Páscoa é um evento religioso cristão, normal...
# 12 2014-04-21  Joaquim José da Silva Xavier, o Tiradentes foi...
# 13 2014-01-05  O Dia do Trabalhador ou Dia Internacional dos ...
# 14 2014-11-05  O Dia das Mães teve a sua origem no princípio ...
# 15 2014-12-06  O Dia dos Namorados ou Dia de São Valentim é u...
# 16 2014-06-19  Ponto Facultativo no País, mas Feriado Municip...
# 17 2014-06-19   conforme a Lei nº 8796 de 09 de dezembro de 2003
# 18 2014-10-08  Em 1909, nos Estados Unidos, Sonora Luise reso...
# 19 2014-08-15  Nossa Senhora da Assunção, Padroeira de Fortal...
# 20 2014-07-09  O Dia da Indepência do Brasil, oficialmente a ...
# 21 2014-12-10  Nossa Senhora da Conceição Aparecida é a padro...
# 22 2014-10-15  FERIADO ESCOLAR - No dia 15 de outubro de 1827...
# 23 2014-10-17  Comemoração do dia do comércio. Em algumas cid...
# 24 2014-10-28  O dia do servidor público é feriado apenas par...
# 25 2014-02-11  O Dia de Finados ou Dia dos Fiéis Defuntos, (c...
# 26 2014-11-15  A Proclamação da República foi um levante polí...
# 27 2014-11-20  Apesar de ser comemorado em todo o território ...
# 28 2014-12-25  O Natal é comemorado anualmente em 25 de Dezem...
#
#                                                  link  \
# 0   http://www.calendario.com.br/feriados-nacionai...
# 1   http://www.calendario.com.br/feriados-nacionai...
# 2   http://www.calendario.com.br/feriados-nacionai...
# 3   http://www.calendario.com.br/feriados-nacionai...
# 4
# 5    http://216.59.16.201:8080/sapl/sapl_documento...
# 6
# 7
# 8   http://216.59.16.201:8080/sapl/sapl_documentos...
# 9   http://www.calendario.com.br/feriados-nacionai...
# 10   http://216.59.16.201:8080/sapl/sapl_documento...
# 11
# 12  http://www.calendario.com.br/feriados-nacionai...
# 13  http://www.calendario.com.br/feriados-nacionai...
# 14
# 15
# 16  http://www.calendario.com.br/feriados-nacionai...
# 17   http://216.59.16.201:8080/sapl/sapl_documento...
# 18
# 19   http://216.59.16.201:8080/sapl/sapl_documento...
# 20  http://www.calendario.com.br/feriados-nacionai...
# 21  http://www.calendario.com.br/feriados-nacionai...
# 22  http://www.calendario.com.br/docs/dia-do-profe...
# 23
# 24
# 25  http://www.calendario.com.br/feriados-nacionai...
# 26  http://www.calendario.com.br/feriados-nacionai...
# 27  http://www.calendario.com.br/feriados-nacionai...
# 28  http://www.calendario.com.br/feriados-nacionai...
#
#                         name  \
# 0                   Ano Novo
# 1                   Carnaval
# 2                   Carnaval
# 3                   Carnaval
# 4            Dia de São José
# 5                   São José
# 6        Data Magna do Ceará
# 7             Dia da Mentira
# 8   Aniversário de Fortaleza
# 9          Sexta-Feira Santa
# 10         Sexta-feira Santa
# 11                    Páscoa
# 12         Dia de Tiradentes
# 13           Dia do Trabalho
# 14              Dia das Mães
# 15         Dia dos Namorados
# 16            Corpus Christi
# 17            Corpus Christi
# 18              Dia dos Pais
# 19    N. Senhora da Assunção
# 20   Independência do Brasil
# 21   Nossa Senhora Aparecida
# 22          Dia do Professor
# 23           Dia do Comércio
# 24   Dia do Servidor Público
# 25            Dia de Finados
# 26  Proclamação da República
# 27         Consciência Negra
# 28                     Natal
#
#                                       raw_description               type  \
# 0                                                 NaN   Feriado Nacional
# 1                                                 NaN        Facultativo
# 2                                                 NaN        Facultativo
# 3                                                 NaN        Facultativo
# 4                        Padroeiro do Estado do Ceará        Facultativo
# 5   Dia de São José, padroeiro do estado do Ceará,...  Feriado Municipal
# 6   É a data magna onde ocorrem as comemorações do...   Feriado Estadual
# 7                                                 NaN   Dia Convencional
# 8           conforme Lei nº 7535, de 16 de junho 1994  Feriado Municipal
# 9                                                 NaN   Feriado Nacional
# 10   conforme a Lei nº 8796 de 09 de dezembro de 2003  Feriado Municipal
# 11                                                NaN   Dia Convencional
# 12                                                NaN   Feriado Nacional
# 13                                                NaN   Feriado Nacional
# 14                                                NaN   Dia Convencional
# 15                                                NaN   Dia Convencional
# 16                                                NaN        Facultativo
# 17   conforme a Lei nº 8796 de 09 de dezembro de 2003  Feriado Municipal
# 18                                                NaN   Dia Convencional
# 19  Nossa Senhora da Assunção, Padroeira de Fortal...  Feriado Municipal
# 20                                                NaN   Feriado Nacional
# 21                                                NaN   Feriado Nacional
# 22                                                NaN        Facultativo
# 23                                                NaN   Dia Convencional
# 24                                                NaN        Facultativo
# 25                                                NaN   Feriado Nacional
# 26                                                NaN   Feriado Nacional
# 27                                                NaN   Dia Convencional
# 28                                                NaN   Feriado Nacional
#
#     type_code
# 0           1
# 1           4
# 2           4
# 3           4
# 4           4
# 5           3
# 6           2
# 7           9
# 8           3
# 9           1
# 10          3
# 11          9
# 12          1
# 13          1
# 14          9
# 15          9
# 16          4
# 17          3
# 18          9
# 19          3
# 20          1
# 21          1
# 22          4
# 23          9
# 24          4
# 25          1
# 26          1
# 27          9
# 28          1

# %%
dataset = pd.read_csv('../data/bicicletar/graph_datasets/climate_rides.csv')

# %%
from seaborn import regplot

# %%
import seaborn as sns; sns.set(color_codes=True)
ax = sns.regplot(x=(dataset['M_0']+dataset['F_0']), y=dataset['max_pr'])

# %%
ax = sns.regplot(x=(dataset['M_0']+dataset['F_0']), y=dataset['max_tmp'])

# %%
filter_dataset = dataset[dataset['max_pr']>5]
ax = sns.regplot(y=(filter_dataset['M_0']+filter_dataset['F_0']), x=filter_dataset['max_pr'])

# %%
dataset['max_pr'].plot.hist(bins=70)
